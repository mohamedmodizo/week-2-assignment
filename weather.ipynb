# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot

# %%
#load dataset
df=pd.read_csv(r'C:\Users\Admin\OneDrive\Desktop\COMPUTER SCIENCE ONLINE CLASS\weather1\1. Weather Data.csv')
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#description of dataset or summary statistics
df.describe(include='all')
# Out:
#               Date/Time       Temp_C  Dew Point Temp_C    Rel Hum_%  \
# count              8784  8784.000000       8784.000000  8784.000000
# unique             8784          NaN               NaN          NaN
# top     12/31/2012 7:00          NaN               NaN          NaN
# freq                  1          NaN               NaN          NaN
# mean                NaN     8.798144          2.555294    67.431694
# std                 NaN    11.687883         10.883072    16.918881
# min                 NaN   -23.300000        -28.500000    18.000000
# 25%                 NaN     0.100000         -5.900000    56.000000
# 50%                 NaN     9.300000          3.300000    68.000000
# 75%                 NaN    18.800000         11.800000    81.000000
# max                 NaN    33.000000         24.400000   100.000000
#
#         Wind Speed_km/h  Visibility_km    Press_kPa       Weather
# count       8784.000000    8784.000000  8784.000000          8784
# ...

# %%
#check for missing values
df.isnull
# Out:
# <bound method DataFrame.isnull of              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#check for missing values and count in each row
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#looping
for col in df.select_dtypes(include=['object']).columns:
    print(f'Unique values in {col}:')
    print(df[col].value_counts())
    print("\n")
# Out:
# Unique values in Date/Time:
# Date/Time
# 12/31/2012 7:00    1
# 12/31/2012 6:00    1
# 12/31/2012 5:00    1
# 12/31/2012 4:00    1
# 12/31/2012 3:00    1
#                   ..
# 1/1/2012 4:00      1
# 1/1/2012 3:00      1
# 1/1/2012 2:00      1
# 1/1/2012 1:00      1
# 1/1/2012 0:00      1
# Name: count, Length: 8784, dtype: int64
#
#
# Unique values in Weather:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# ...

# %%
# Identify categorical and numerical columns
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

print("Categorical Columns:", categorical_columns)
print("Numerical Columns:", numerical_columns)
# Out:
# Categorical Columns: Index(['Date/Time', 'Weather'], dtype='object')
# Numerical Columns: Index(['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%', 'Wind Speed_km/h',
#        'Visibility_km', 'Press_kPa'],
#       dtype='object')

# %%
# Summary of categorical data
for column in categorical_columns:
    print(f"\nColumn: {column}")
    print("Number of unique values:", df[column].nunique())
    print("Value counts:")
    print(df[column].value_counts())
# Out:
# Column: Date/Time
# Number of unique values: 8784
# Value counts:
# Date/Time
# 12/31/2012 7:00    1
# 12/31/2012 6:00    1
# 12/31/2012 5:00    1
# 12/31/2012 4:00    1
# 12/31/2012 3:00    1
#                   ..
# 1/1/2012 4:00      1
# 1/1/2012 3:00      1
# 1/1/2012 2:00      1
# 1/1/2012 1:00      1
# 1/1/2012 0:00      1
# Name: count, Length: 8784, dtype: int64
#
# Column: Weather
# Number of unique values: 50
# Value counts:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# ...

# %%
# Summary statistics for numerical data
print("\nSummary Statistics for Numerical Columns:")
print(df[numerical_columns].describe())
# Out:
# Summary Statistics for Numerical Columns:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Box plots for numerical data to check for outliers
for column in numerical_columns:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# Bar charts for categorical data to see frequency of each category
for column in categorical_columns:
    plt.figure(figsize=(10, 4))
    sns.countplot(x=df[column])
    plt.title(f'Frequency of {column}')
    plt.xticks(rotation=90)
    plt.show()

# %%
#check for dublicates
duplicates = df[df.duplicated()]
print("Number of duplicate records:", duplicates.shape[0])
# Out:
# Number of duplicate records: 0

# %%
#statistical summary
# Display statistical summary of numerical columns
numerical_summary = df.describe()
print(numerical_summary)
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
# Display summary statistics for categorical columns
categorical_summary = df.describe(include=['object', 'category'])
print(categorical_summary)
# Out:
#               Date/Time       Weather
# count              8784          8784
# unique             8784            50
# top     12/31/2012 7:00  Mainly Clear
# freq                  1          2106

# %%
def detect_outliers(df, feature):
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    outliers = df[(df[feature] < lower_bound) | (df[feature] > upper_bound)]
    return outliers

# %%
#no outlier in weather data provided

# %%
import matplotlib.pyplot as plt

# Histogram of Temperature
plt.figure(figsize=(10, 6))
plt.hist(df['Temp_C'], bins=30, color='blue', alpha=0.7)
plt.title('Distribution of Temp_C')
plt.xlabel('Temp_C (°C)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Histogram of Humidity
plt.figure(figsize=(10, 6))
plt.hist(df['Rel Hum_%'], bins=30, color='green', alpha=0.7)
plt.title('Distribution of Rel Hum_%')
plt.xlabel('Rel Hum_% (%)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Histogram of Wind Speed
plt.figure(figsize=(10, 6))
plt.hist(df['Wind Speed_km/h'], bins=30, color='red', alpha=0.7)
plt.title('Distribution of Wind Speed_km/h')
plt.xlabel('Wind Speed_km/h (km/h)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Box Plot for Temperature
plt.figure(figsize=(8, 4))
plt.boxplot(df['Temp_C'], vert=False)
plt.title('Box Plot of Temp_C')
plt.xlabel('Temp_C (°C)')
plt.show()

# Box Plot for Humidity
plt.figure(figsize=(8, 4))
plt.boxplot(df['Rel Hum_%'], vert=False)
plt.title('Box Plot of Rel Hum_%')
plt.xlabel('Rel Hum_% (%)')
plt.show()

# Box Plot for Wind Speed
plt.figure(figsize=(8, 4))
plt.boxplot(df['Wind Speed_km/h'], vert=False)
plt.title('Box Plot of Wind Speed_km/h')
plt.xlabel('Wind Speed_km/h (km/h)')
plt.show()

# %%
import seaborn as sns

# Density Plot for Temperature
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Temp_C'], shade=True, color='blue')
plt.title('Density Plot of Temp_C')
plt.xlabel('Temp_C (°C)')
plt.ylabel('Density')
plt.show()

# Density Plot for Humidity
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Rel Hum_%'], shade=True, color='green')
plt.title('Density Plot of Rel Hum_%')
plt.xlabel('Rel Hum_% (%)')
plt.ylabel('Density')
plt.show()

# Density Plot for Wind Speed
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Wind Speed_km/h'], shade=True, color='red')
plt.title('Density Plot of Wind Speed_km/h')
plt.xlabel('Wind Speed_km/h (km/h)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12316\2820639168.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Temp_C'], shade=True, color='blue')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12316\2820639168.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Rel Hum_%'], shade=True, color='green')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12316\2820639168.py:21: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Wind Speed_km/h'], shade=True, color='red')

# %%
print(df.columns)
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
#Time series plot
import pandas as pd


# Convert the date column to datetime type
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# Ensure the date column is set as the index of the dataframe
df.set_index('Date/Time', inplace=True)

# %%
#ploting time series graph
import matplotlib.pyplot as plt

# Plot Temperature over Time
plt.figure(figsize=(14, 7))
plt.plot(df['Temp_C'], label='Temp_C (°C)', color='red')
plt.title('Temp_C Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Temp_C (°C)')
plt.legend()
plt.grid(True)
plt.show()

# Plot Humidity over Time
plt.figure(figsize=(14, 7))
plt.plot(df['Rel Hum_%'], label='Rel Hum_% (%)', color='blue')
plt.title('Rel Hum_% Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Rel Hum_% (%)')
plt.legend()
plt.grid(True)
plt.show()

# Plot Wind Speed over Time
plt.figure(figsize=(14, 7))
plt.plot(df['Wind Speed_km/h'], label='Wind Speed_km/h (km/h)', color='green')
plt.title('Wind Speed_km/h Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Wind Speed_km/h (km/h)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#seasonal variation
# Plot Temperature with a Rolling Mean (e.g., 30-day moving average)
plt.figure(figsize=(14, 7))
plt.plot(df['Temp_C'], label='Daily Temp_C', color='red', alpha=0.5)
plt.plot(df['Temp_C'].rolling(window=30).mean(), label='30-Day Moving Average', color='black')
plt.title('Temp_C Trend with Seasonal Highlight')
plt.xlabel('Date')
plt.ylabel('Temp_C (°C)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#seasonal variation
# Plot Relative Humidity with a Rolling Mean (e.g., 30-day moving average)
plt.figure(figsize=(14, 7))
plt.plot(df['Rel Hum_%'], label='Daily Temp_C', color='red', alpha=0.5)
plt.plot(df['Rel Hum_%'].rolling(window=30).mean(), label='30-Day Moving Average', color='green')
plt.title('Rel Hum_% Trend with Seasonal Highlight')
plt.xlabel('Date')
plt.ylabel('Rel Hum_% (°C)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#seasonal variation
# Plot Winf Speed with a Rolling Mean (e.g., 30-day moving average)
plt.figure(figsize=(14, 7))
plt.plot(df['Wind Speed_km/h'], label='Daily Temp_C', color='red', alpha=0.5)
plt.plot(df['Wind Speed_km/h'].rolling(window=30).mean(), label='30-Day Moving Average', color='green')
plt.title('Wind Speed_km/h Trend with Seasonal Highlight')
plt.xlabel('Date')
plt.ylabel('Wind Speed_km/h (°C)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Identify numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
print("Numeric columns considered for correlation:", numeric_cols)
# Out:
# Numeric columns considered for correlation: Index(['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%', 'Wind Speed_km/h',
#        'Visibility_km', 'Press_kPa'],
#       dtype='object')

# %%
correlation_matrix = df[numeric_cols].corr()
print(correlation_matrix)
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Temp_C            1.000000          0.932714  -0.220182        -0.061876
# Dew Point Temp_C  0.932714          1.000000   0.139494        -0.095685
# Rel Hum_%        -0.220182          0.139494   1.000000        -0.092743
# Wind Speed_km/h  -0.061876         -0.095685  -0.092743         1.000000
# Visibility_km     0.273455          0.050813  -0.633683         0.004883
# Press_kPa        -0.236389         -0.320616  -0.231424        -0.356613
#
#                   Visibility_km  Press_kPa
# Temp_C                 0.273455  -0.236389
# Dew Point Temp_C       0.050813  -0.320616
# Rel Hum_%             -0.633683  -0.231424
# Wind Speed_km/h        0.004883  -0.356613
# Visibility_km          1.000000   0.231847
# Press_kPa              0.231847   1.000000

# %%
# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm',
            xticklabels=correlation_matrix.columns,
            yticklabels=correlation_matrix.columns)
plt.title('Correlation Matrix for Weather Parameters')
plt.show()

# %% [markdown]
# The above correlation matrix makes pictorial representations of the relationships between the following weather parameters: temperature, dew point temperature, relative humidity, wind speed, visibility, and atmospheric pressure. Here is the interpretation of the key insights from the correlation matrix:
#
#  1. **Temperature and Dew Point Temperature**
# - **Correlation Coefficient: 0.93**
# - This very high positive correlation suggests that the higher the temperature, the higher the dew point temperature it tends to be. This relationship is very common due to the fact that warmer air is capable of holding more moisture, hence a higher dew point.
#
# 2. **Temperature and Relative Humidity**
# - **Correlation Coefficient: -0.22**
# - This negative correlation may indicate that higher temperatures are linked with lower relative humidity, which makes sense since warm air has greater capacity to retain more moisture. This in turn implies that the relative humidity becomes less unless there is an increase in the corresponding moisture content.
#
# 3. **Temperature and Visibility**
# - **Correlation Coefficient: 0.27**
# - A small positive correlation would indicate that higher temperatures might give comparatively better visibility conditions, perhaps because less moisture at a high temperature results in less fog or haze.
#
# 4. **Temperature and Atmospheric Pressure**
# - **Correlation Coefficient: -0.24**
# - This negative correlation tells that with the rise in temperature, atmospheric pressure will be low, which complies with the usual meteorological patterns where low pressure is generally associated with warmer conditions.
#
# 5. **Relative Humidity and Visibility**
# - **Correlation Coefficient: -0.63**
# - A high negative correlation, significant, stating that with increasing relative humidity, the visibility reduces correspondingly. This relationship may be expected since high moisture content in the air, such as fog or rain, can drastically reduce the line of sight.
#
#  6. **Wind Speed and Atmospheric Pressure**
# - **Correlation Coefficient: -0.36**
# • This negative correlation suggests that higher wind speed often goes hand in hand with lower atmospheric pressure, a common scenario in stormy weather conditions where pressure drops often lead to increased wind speeds.
# 7. ** Visibility and Atmospheric Pressure **
# • ** Correlation Coefficient: 0.23 **
# → High positive correlation: High atmospheric pressures, which often bring clear skies and stable weather, tend to result in good visibility.
# These relationships come in handy for a meteorologist or a climate scientist in making more accurate weather forecasts. For example, if the temperature is known to strongly correlate with the dew point, one can establish dew and frost events accordingly.
# Weather Forecasting and Analysis: The relationships can be beneficial to a meteorologist or a climate scientist in making more efficient weather forecasts. Suppose the temperature is known to be highly correlated with the dew point; one can use this to establish dew and frost events accordingly.
# Environmental and Urban Planning: Knowing how visibility varies with respect to humidity and pressure can give valuable insights while designing any visibility dependent activity like transportation and aeronautical planning.
# - **Agricultural Planning**: Relations between temperature, humidity, and pressure play a very important role in agriculture. These have to do with irrigation and time for planting.
#
#  Conclusion:
# This correlation matrix helps to clearly define how the different parameters of weather interact with one another. It is through the study of these relationships that a better understanding of the dynamics of weather patterns is likely to be arrived at; this information is quite important in many practical applications, ranging from everyday weather forecasting to long-term climate change studies.

# %%
# Extract year and month from the Date column
df['Year'] = df.index.year
df['Month'] = df.index.month

# %%
# Plotting monthly averages of temperature
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(df['Temp_C'], label='Average Monthly Temp_C', color='red')
plt.title('Monthly Average Temp_C Over Years')
plt.xlabel('Year, Month')
plt.ylabel('Temp_C (°C)')
plt.legend()
plt.grid(True)
plt.show()

# Plotting monthly averages of humidity
plt.figure(figsize=(14, 7))
plt.plot(df['Rel Hum_%'], label='Average Monthly Rel Hum_%', color='blue')
plt.title('Monthly Average Rel Hum_% Over Years')
plt.xlabel('Year, Month')
plt.ylabel('Rel Hum_% (%)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The plot below shows the trends of monthly average relative humidity from January 2012 to January 2013. Here is how one might interpret the plot:
#
# ### Key Observations:
#
# 1. **Fluctuations**: The relative humidity has major fluctuations throughout the year. These fluctuations range from just above 40% to nearly 100%, showing a strong variation in moisture content within the air.
#
# 2. **Seasonal Patterns**: Again, with this kind of volatility in the plot, no clear seasonal pattern correlates to times of the year in any meaningful way. Indeed, the relative humidity seems to rise and fall sharply sometimes within short periods, an indication that possibly something other than seasonal transitions might be involved in these changes.
#
# 3. High Variability: The sharp peaks and deep troughs indicate that there are rapid changes in atmospheric conditions. This could be a result of the local weather phenomena, geographical features, or other environmental factors that are affecting the level of humidity.
#
# 4. **Possible Weather Events**: Those spikes, almost to 100% RH, may show the presence of rain or fog if these peaks were to match known weather events. Similarly, the drops to lower levels could show dry spells.
#
# ### Implications:
#
# * **Weather Analysis**: The data has extreme variability in humidity levels over the region. It could be a major player in local climate conditions, weather forecasting, and daily activities.
# - **Agricultural Planning**: Knowing these trends in humidity is important for agricultural purposes; they influence crop hydration needs and pest activity.
#
# - **Urban Planning and Health**: Urban planners and public health officials could use such data to anticipate, and thereby temper, air quality problems; higher humidity can aggravate some health conditions, such as asthma.
#
# ### Conclusion:
#
# The plot points out how complex it may be to try and predict humidity trends, the detailed analysis required to understand the causes of such variability. It foregrounds the need for continuous monitoring in order to prepare better and respond to changes in environmental conditions arising from the changing levels of humidity.

# %%
# Plot temperature and humidity over time
plt.figure(figsize=(14, 7))
plt.subplot(2, 1, 1)  # Two rows, one column, first subplot
plt.plot(df['Temp_C'], label='Temp_C', color='red')
plt.title('Temp_C Trends')
plt.legend()

plt.subplot(2, 1, 2)  # Two rows, one column, second subplot
plt.plot(df['Rel Hum_%'], label='Rel Hum_%', color='blue')
plt.title('Rel Hum_% Trends')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Temperature and relative humidity (RH) are plotted for a one-year time series, from January 2012 to January 2013, in degrees Celsius and percentage, respectively. According to the plots, here is an interpretation:
#
# ### Trends in Temperature (Top Plot)
# - **Seasonal Pattern**: In this temperature plot, there is evident seasonality. The temperature peaks during the middle of the year—June to August—a characteristic common in summer for the Northern Hemisphere. The lowest temperatures occur toward the beginning and end of the year, indicative of winter conditions.
# - **Volatility**: These temperature swings are relatively sharp and frequent, so it could be that there are warm and cold fronts frequenting the area, or it might be a simple daily variation in temperatures.
# - **Anomalies**: There are some abrupt spikes and drops over the course of the year. For example, there appears to be an onset of sudden fall in temperature around October. It could be that there was a climatic change, such as a cold snap.
#
# ###
# Relative Humidity Trends (Bottom Plot)
# - **General Behavior**: The relative humidity is very variable, ranging from about 40% to almost 100%. This might imply high variability in the moisture content of air.
# - **Seasonal Influence**: Unlike temperature, no pattern can be clearly related to the expected seasons. However, higher peaks of humidity might still be related to specific weather, like rain or storms.
# - **Consistency**: That is to say, some consistent fluctuation pattern does not appear to be there without any prolonged sojourn at extreme highs and lows. This is rather typical of many regions where the humidity can vary from one day to another.
#
# ### Correlation Between Temperature and Humidity
# - **Inverse Relationship**: From a broad perspective, there seems to be an inverse relationship wherein the humidity appears to decrease when there is an increase in temperature, more prevalent during the middle of the year when temperatures are at their peak. However, this is not a strict rule, as humidity itself is a highly variable phenomenon and does not really show an inverse behavior vis-à-vis changes in temperature.
#
# ### Possible Implications and Insights
# • **Climatic Conditions**: The data could suggest a more temperate climate, with well-defined seasonal trends in temperature. Besides, frequent changes in humidity could indicate proximity to large bodies of water or varying weather systems.
# • **Weather Events**: Sharp changes in both plots could be indicative in pinpointing specific weather events. For instance, sudden drops in temperature with spikes in humidity might indicate storm occurrences.
# **Planning and Prediction**: Knowledge of these patterns is important in activities that are weather dependent, like agriculture, outdoor events, and even health-related activities. These observed patterns could also improve predictive models.
#
# The analysis offers some basic knowledge of the dynamics of the weather as observed in the area, thus helping to guide further studies in more detailed aspects or operational planning based on climatic conditions.

# %%
# Calculate the Z-score for each data point
df['Temp_C_Z'] = (df['Temp_C'] - df['Temp_C'].mean()) / df['Temp_C'].std()
df['Rel Hum_%_Z'] = (df['Rel Hum_%'] - df['Rel Hum_%'].mean()) / df['Rel Hum_%'].std()

# Filter out data points where the absolute Z-score is greater than 3
temp_anomalies = df[np.abs(df['Temp_C_Z']) > 3]
humidity_anomalies = df[np.abs(df['Rel Hum_%_Z']) > 3]

print("Temperature Anomalies:\n", temp_anomalies)
print("Rel Hum_% Anomalies:\n", humidity_anomalies)
# Out:
# Temperature Anomalies:
#  Empty DataFrame
# Columns: [Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather, Year, Month, Temp_C_Z, Rel Hum_%_Z]
# Index: []
# Rel Hum_% Anomalies:
#  Empty DataFrame
# Columns: [Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather, Year, Month, Temp_C_Z, Rel Hum_%_Z]
# Index: []

# %%
#Correlation with External Events
#Cross-reference anomaly dates with known weather events
known_events = {'2023-05-16': 'Hurricane', '2024-07-04': 'Heatwave'}
anomaly_dates = temp_anomalies.index.union(humidity_anomalies.index)

for date in anomaly_dates:
    if date.strftime('%Y-%m-%d') in known_events:
        print(f"Anomaly on {date.date()} may be due to {known_events[date.strftime('%Y-%m-%d')]}")

# %% [markdown]
# Key Takeaways of Weather Data Analysis
#
# Weather Forecasting
# - **Seasonal Trends**: Historical data on seasonal variation acts as a driver of accuracy in the forecast of weather.
# - **Anomaly Detection**: The tuning and betterment of its predictive models with past information on weather anomalies helps to predict unusual weather.
# - **Correlation Analysis**: The relationship between weather parameters such as humidity and rainfall is used to fine-tune forecasting algorithms.
#
# Agriculture
# Crop Planning: Seasonal weather data enables farmers to plan on planting and harvesting dates.
# - **Irrigation Management**: Efficient water management strategies, based on humidity and rainfall predictions, improve crop yields.
#
#  Urban Planning and Infrastructure
# - **Disaster Preparedness**: Building robust infrastructure in cities to face extreme weather conditions using historical weather patterns.
# - **Energy Management**: Weather forecasting helps to modulate energy supply with fluctuating weather conditions against demand efficiently.
#
# Environmental Management
# - **Climate Change Monitoring**: Trends in weather data continuously help in understanding and mitigating the effects of climate change.
# - **Wildlife Conservation**: Weather information helps manage their natural environments, particularly adapting to shifts that affect the wildlife's own resources.
#
# Public Health
# - **Disease Outbreak Prediction**: Pre-emptive analysis of weather conditions can predict the onset of conditions conducive to outbreaks of disease vectors like mosquitoes, which can trigger health warnings and precautionary measures in time.
# - **Heatwave Alerts**: Long-term trend data of temperature support public health warnings and the formulation of mitigation measures against heat-related health effects.
#
# Tourism and Event Planning
# - **Seasonal Activity Planning**: Tourism enterprises will align and maximize offers according to usual weather conditions to improve the experience of visitors.
# - **Event Safety**: The organizers of events will plan activities in times with better weather conditions to minimize the occurrence of risks and troubles.
#
# Conclusion
# Weather data analysis finds its application across a range of industries, bringing about immense decisiveness in decision-making for better safety and efficient utilization of resources. This wide application underlines the importance of meteorological data in daily operations and strategic planning across fields of activity.

# %% [markdown]
# Key Insights from EDA: High Correlation Between Temperature and Dew Point:
#
# The near-perfect correlation of 0.93 suggests that dew point temperature is highly correlated with air temperature. This insight is very key in predicting condensation and fog, which may affect many things from driving conditions to agricultural planning. Inverse Relationship Between Temperature and Relative Humidity:
#
# The negative correlation (-0.22) between temperature and relative humidity is modest, but it underlines a typical meteorological pattern: with rising temperatures, the air has greater moisture-carrying ability, hence often bringing down the relative humidity unless moisture inputs rise to compensate, for instance, from evaporation or precipitation. Relative Humidity Strongly Negatively Affects Visibility:
#
# The strongest correlation among them is noted between relative humidity and visibility, which stands at -0.63. High humidity, leading to large portions of the atmosphere being fogged up, definitely reduces the visibility and impacts transport and safety.
# Wind Speed vs. Atmospheric Pressure:
#
# A negative correlation of -0.36 perhaps indicates that the atmospheric pressure often decreases with an increased wind speed, especially during a storm.
# Use of Pressure to Reveal Weather Stability:
#
# The negative correlation for temperature versus pressure, -0.24, together with the positive correlation for visibility with pressure, of 0.23, speaks to high pressure generally going with clearer and more stable weather.
# Most Interesting or Surprising Findings:
# Dew Point as a Predictor of Weather Feel:
# The high correlation between temperature and dew point states that the dew point is very often a good indication of how hot or cold it actually "feels" to human beings and, hence, the perceived temperature and comfort levels are affected by it.
# Subtle Influences on Visibility:
# What was surprising to me was the high effect of humidity on visibility but no correlation with wind speed. This again emphasizes the role of moisture content above that of air movement on reducing visibility.
# Pressure's Effects on Visibility and Weather Changes:
# The interdependencies pressure shows with various factors, particularly the strong effects it exerts on visibility and its average ones on temperature changes, provide some satisfying answers to questions on the predictive power for weather forecasting.
# Real-World Implications of Such Findings:
# Weather Forecasting:
#
# These correlations can improve weather models, thus bettering predictions associated with fog, storms, and general weather.
# Agricultural Sector:
#
# Knowing humidity and dew point can be instrumental in taking decisions on irrigation and in frost/heat damage protection of crops.
# Public Safety and Transportation:
#
# The knowledge of the visibility conditions because of humidity and pressure would help in issuing advisories for fog and storms well in advance so that utmost safety for road and air travel can be achieved.
# Urban and Environmental Planning:
#
# Knowing how different weather parameters interact can help to make better decisions when it comes to planning—from adjusting building designs according to local climatic conditions to the development of urban green space mitigating the impacts of bad weather.

# %% [markdown]
# Knowing the insights from a correlation matrix of weather parameters in itself is of immense value for any weather prediction and several practical applications. Here's how these can be effectively utilized:
#
# 1. Prediction and Forecasting of Weather
# Seasonal Trends: This knowledge of seasonal and monthly variations helps meteorologists make better forecasts based on historical trends. By recognizing the kinds of weather most common for different times of the year, forecasts could include that information.
# Anomaly Detection: Past weather anomalies can be studied to further tune predictive models to predict such anomalies in the weather. This can be done by introducing factors that lead to the anomaly previously into the models for better prediction when those conditions arise again.
# Correlation Analysis: Relations between Weather Parameters: Relations amongst parameters like humidity and rainfall are used to fine-tune the algorithm for better forecasting.
# 2. Agriculture
# Crop Planning: Seasonal weather data regarding the best times to sow and harvest is passed on to farmers.
# Irrigation Management: Humidity and rain fall predictions aid efficient water management schemes for better yields.
# 3. Urban Planning and Infrastructure
# Disaster Preparedness: Building sturdy infrastructure with historical weather patterns as a guide helps cities prepare for extreme weather.
# Energy Management: Weather forecasting helps in adjusting the energy supply during varying weather conditions to match demand efficiently.
# 4. Environmental Management
# Monitoring Climate Change: Continued analysis of trends in weather data assists in studying and addressing the impacts of climate change.
# Wildlife Conservation: Weather insights are useful in managing natural habitats, especially adjusting to changes affecting the wildlife resources.
# 5. Public Health
# Disease Outbreak Prediction: Predictive weather analysis helps in anticipating conditions that favor the development of diseases-carrying vectors such as mosquitoes to enable pre-emptive measures in health.
# Heatwave Alerts: Trend data of temperature informs public health warnings and preparation measures against heat-related health issues.
# 6. Tourism and Event Planning
# Seasonal Activity Planning: Tourism businesses will optimize their offerings based on the typical weather conditions to enhance the experience of the visitors.
# Event Safety: Event planners schedule activities during periods with favorable weather to minimize risks and disruptions.
